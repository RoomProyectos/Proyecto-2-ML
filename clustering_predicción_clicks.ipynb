# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# GridSearchCV
from sklearn.model_selection import GridSearchCV

# Train, Test
from sklearn.model_selection import train_test_split

# Metricas para regresiones
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Regresores
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import RadiusNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Validacion
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import KFold

# %%
df = pd.read_csv("Data/Datos_pred.csv")

# %% [markdown]
# ## PREPROCESAMIENTO ##

# %%
# normalización

X = df_tt.iloc[:, 2:]

x_scaler = MinMaxScaler()
X = x_scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
kmeans.inertia_
# Out:
# 1112.7533208675916

# %%
inercias = list() 
  
for k in range(2, 11): 
    
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(X)    
    
    inercias.append(kmeans.inertia_) 
    
inercias
# Out:
# [1542.3928061922397,
#  1112.7562960534715,
#  959.5962154960947,
#  832.1803566493238,
#  722.8044217804397,
#  675.7370802206476,
#  619.8068891497927,
#  576.5001810723676,
#  543.3192625059378]

# %%
plt.figure(figsize = (10, 8))

plt.plot(range(1, len(inercias) + 1), inercias, marker = "x", color = "blue")

plt.xlabel("K's") 
plt.ylabel("Inercia") 

plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
df_tt.iloc[:, 2:]["Cluster"] = kmeans.labels_

df_tt.head()
# Out:
#                                              Titular  \
# 0  Que arresten a los líderes de Israel por críme...
# 1  El pelotazo de los curas salesianos con una pi...
# 2  Países Bajos no participa en el segundo ensayo...
# 3  Todos los israelíes están entrenados en hasbar...
# 4  Cuando Einstein llamó “fascistas” a los gobern...
#
#                                                  URL  Meneos  Clicks  \
# 0  https://old.meneame.net/story/arresten-lideres...      81   111.0
# 1  https://old.meneame.net/story/pelotazo-curas-s...      73   336.0
# 2  https://old.meneame.net/story/paises-bajos-no-...     123  1275.0
# 3  https://old.meneame.net/story/todos-israelies-...     117  1256.0
# 4  https://old.meneame.net/story/cuando-einstein-...     260   415.0
#
#    Positivos  Anonimos  Negativos  Comentarios  Karma    Delay  Cluster
# 0       51.0      30.0        4.0         11.0  463.0   7655.0        3
# 1       43.0      30.0        3.0         20.0  441.0  10093.0        3
# 2       72.0      51.0        3.0         39.0  460.0   1683.0        3
# 3       69.0      48.0        5.0         24.0  410.0  13713.0        3
# 4      139.0     121.0        2.0         17.0  461.0  26628.0        3

# %%
df_tt["Cluster"].value_counts()
# Out:
# Cluster
# 3    92787
# 4    50300
# 1    31437
# 2    12578
# 0     6569
# Name: count, dtype: int64
